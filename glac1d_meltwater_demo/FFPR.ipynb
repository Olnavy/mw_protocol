# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import sys
sys.path.append('glac1d_meltwater')
import glac1d_toolbox as tb
# Out:
# /home/olnavy/anaconda3/envs/Olnavy/lib/python3.7/site-packages/xarray/core/merge.py:17: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
## PACIFIC

# East Pacific
lat_EPac1_min, lat_EPac1_max, lon_EPac1_min, lon_EPac1_max = 50, 60, 191, 215.5
lat_EPac2_min, lat_EPac2_max, lon_EPac2_min, lon_EPac2_max = 50, 60, 215.5, 225.5
lat_EPac3_min, lat_EPac3_max, lon_EPac3_min, lon_EPac3_max = 38.5, 60, 225.5, 234.5
lat_EPac4_min, lat_EPac4_max, lon_EPac4_min, lon_EPac4_max = 33.75, 38.5, 230, 260
lat_EPac5_min, lat_EPac5_max, lon_EPac5_min, lon_EPac5_max = 28.5, 33.75, 234.5, 260
# Russia Pacific
lat_RussPac1_min, lat_RussPac1_max, lon_RussPac1_min, lon_RussPac1_max = 58, 68, 178, 191

# New Zealand (South)
lat_SNZPac1_min, lat_SNZPac1_max, lon_SNZPac1_min, lon_SNZPac1_max = -47.5, -43.75, 167, 176
# New Zealand (North)
lat_NNZPac1_min, lat_NNZPac1_max, lon_NNZPac1_min, lon_NNZPac1_max = -43.75, -39, 165, 174.25


## ARCTIC

# Atlantic Greenland Iceland
lat_AtlGr1_min, lat_AtlGr1_max, lon_AtlGr1_min, lon_AtlGr1_max = 58, 71.25, 317, 337.25
lat_AtlGr2_min, lat_AtlGr2_max, lon_AtlGr2_min, lon_AtlGr2_max = 62.5, 63.75, 337.25, 339.5

# E Greenland & Iceland
lat_EGrIce1_min, lat_EGrIce1_max, lon_EGrIce1_min, lon_EGrIce1_max = 63.75, 81, 337.25, 346
lat_EGrIce2_min, lat_EGrIce2_max, lon_EGrIce2_min, lon_EGrIce2_max = 68.75, 83, 346, 357

# E Iceland
lat_EIceland1_min, lat_EIceland1_max, lon_EIceland1_min, lon_EIceland1_max = 63.75, 68.75, 346, 351

# UK Atlantic
lat_UKAtl1_min, lat_UKAtl1_max, lon_UKAtl1_min, lon_UKAtl1_max = 46, 62.5, 346.75, 360

# Eurasian GIN Seas
lat_EurGIN1_min, lat_EurGIN1_max, lon_EurGIN1_min, lon_EurGIN1_max = 68, 80, 3, 9.5
lat_EurGIN2_min, lat_EurGIN2_max, lon_EurGIN2_min, lon_EurGIN2_max = 68, 78, 9.5, 24.375
lat_EurGIN3_min, lat_EurGIN3_max, lon_EurGIN3_min, lon_EurGIN3_max = 60, 68, 0, 16
lat_EurGIN4_min, lat_EurGIN4_max, lon_EurGIN4_min, lon_EurGIN4_max = 50, 60.0, 0.0, 13
lat_EurGIN5_min, lat_EurGIN5_max, lon_EurGIN5_min, lon_EurGIN5_max = 66.25, 68, 16, 24.375
lat_EurGIN6_min, lat_EurGIN6_max, lon_EurGIN6_min, lon_EurGIN6_max = 68, 80, 0., 3  # New one, only for catching
lat_Baltic1_min, lat_Baltic1_max, lon_Baltic1_min, lon_Baltic1_max = 50, 60.0, 13, 30  # only for catching the water
lat_Baltic2_min, lat_Baltic2_max, lon_Baltic2_min, lon_Baltic2_max = 60, 66.25, 16, 38  # not for spreading

# South Iceland
lat_SIceland1_min, lat_SIceland1_max, lon_SIceland1_min, lon_SIceland1_max = 60, 63.75, 339.5, 346.75

# Siberian Arctic
lat_SibArc1_min, lat_SibArc1_max, lon_SibArc1_min, lon_SibArc1_max = 68, 82, 173, 191
lat_SibArc2_min, lat_SibArc2_max, lon_SibArc2_min, lon_SibArc2_max = 68, 82, 114.5, 173

# Eurasian Arctic
lat_EurArc1_min, lat_EurArc1_max, lon_EurArc1_min, lon_EurArc1_max = 78, 86, 9.5, 114.5
lat_EurArc2_min, lat_EurArc2_max, lon_EurArc2_min, lon_EurArc2_max = 66.25, 78, 24.375, 114.5
lat_EurArc3_min, lat_EurArc3_max, lon_EurArc3_min, lon_EurArc3_max = 80, 86, 0, 9 # New One - only for catching


## NORTH ATLANTIC

# USA East Coast
lon_USECoast1_min, lon_USECoast1_max, lat_USECoast1_min, lat_USECoast1_max = -70,-52,37,46
lon_USECoast2_min, lon_USECoast2_max, lat_USECoast2_min, lat_USECoast2_max = -70,-65,32,37
lon_USECoast3_min, lon_USECoast3_max, lat_USECoast3_min, lat_USECoast3_max = -81,-70,28.75,40
lon_USECoast4_min, lon_USECoast4_max, lat_USECoast4_min, lat_USECoast4_max = -52,-48,40,46
lon_USECoast5_min, lon_USECoast5_max, lat_USECoast5_min, lat_USECoast5_max = -66,-58,46,50
lon_USECoast6_min, lon_USECoast6_max, lat_USECoast6_min, lat_USECoast6_max = -48,-46,40,46

# Greenland Arctic
lon_GrArc1_min, lon_GrArc1_max, lat_GrArc1_min, lat_GrArc1_max = 279.5,346,81,88

# North American Arctic
lat_NAMArc1_min, lat_NAMArc1_max, lon_NAMArc1_min, lon_NAMArc1_max = 78, 86, 271, 279.5
lat_NAMArc2_min, lat_NAMArc2_max, lon_NAMArc2_min, lon_NAMArc2_max = 68.75, 86, 246, 271
lat_NAMArc3_min, lat_NAMArc3_max, lon_NAMArc3_min, lon_NAMArc3_max = 60, 82, 233, 246
lat_NAMArc4_min, lat_NAMArc4_max, lon_NAMArc4_min, lon_NAMArc4_max = 60, 80, 191, 233
lat_NAMArc5_min, lat_NAMArc5_max, lon_NAMArc5_min, lon_NAMArc5_max = 55, 68.75, 250, 264.375
lat_NWTerr1_min, lat_NWTerr1_max, lon_NWTerr1_min, lon_NWTerr1_max = 55, 60, 235, 246
lat_NWTerr2_min, lat_NWTerr2_max, lon_NWTerr2_min, lon_NWTerr2_max = 55, 66, 246, 250

# Great Lakes
lat_GrLakes1_min, lat_GrLakes1_max, lon_GrLakes1_min, lon_GrLakes1_max = 43, 48.75, -90, -72

# Gulf of Mexico
lat_GoM1_min, lat_GoM1_max, lon_GoM1_min, lon_GoM1_max = 17.7, 28.75, -96.3, -80

# Mediterranean
lat_Med1_min, lat_Med1_max, lon_Med1_min, lon_Med1_max = 29, 40, 0, 41.5
lat_Med2_min, lat_Med2_max, lon_Med2_min, lon_Med2_max = 40, 45, 0, 24
lat_BlckSea1_min, lat_BlckSea1_max, lon_BlckSea1_min, lon_BlckSea1_max = 40, 50, 26, 42  # only for catching the water, not for spreading it
lat_CaspSea1_min, lat_CaspSea1_max, lon_CaspSea1_min, lon_CaspSea1_max = 35, 50, 46, 55  # NEW ONE , only for catching

# Labrador Sea & Baffin Bay
lat_BafLab1_min, lat_BafLab1_max, lon_BafLab1_min, lon_BafLab1_max = 68.75, 80, 275, 317
lat_BafLab2_min, lat_BafLab2_max, lon_BafLab2_min, lon_BafLab2_max = 50, 68.75, 294.25, 317
lat_BafLab3_min, lat_BafLab3_max, lon_BafLab3_min, lon_BafLab3_max = 46, 50, 305.75, 317
lat_HudBay1_min, lat_HudBay1_max, lon_HudBay1_min, lon_HudBay1_max = 48.75, 68.75, 264.375, 294.375 # only for catching the water
lat_HudBay2_min, lat_HudBay2_max, lon_HudBay2_min, lon_HudBay2_max = 51, 54, 260, 264.375 # not for spreading it

## ANTARCTICA

# Patagonia Atlantic
lat_PatAtl1_min, lat_PatAtl1_max, lon_PatAtl1_min, lon_PatAtl1_max = -56.25, -40.0, 290.5, 305
# Patagonia Pacific
lat_PatPac1_min, lat_PatPac1_max, lon_PatPac1_min, lon_PatPac1_max = -57.5, -36, 282, 290.5
lat_PatPac2_min, lat_PatPac2_max, lon_PatPac2_min, lon_PatPac2_max = -57.5, -56.25, 290.5, 294.5

# Antarctic Ross Sea
lat_AARos1_min, lat_AARos1_max, lon_AARos1_min, lon_AARos1_max = -90.0, -68.0, 167.0, 239.0
# Antarctic Amundsen Sea
lat_AAAmund_min, lat_AAAmund_max, lon_AAAmund_min, lon_AAAmund_max = -90.0, -60.0, 239.0, 297.0
# Antarctic Weddell Sea
lat_AAWeddell_min, lat_AAWeddell_max, lon_AAWeddell_min, lon_AAWeddell_max = -90.0, -60.0, 297.0, 360.0
# Antarctic Riiser-Larson Sea
lat_AARiiLar_min, lat_AARiiLar_max, lon_AARiiLar_min, lon_AARiiLar_max = -90.0, -60.0, 0.0, 59
# Antarctic Davis Sea
lat_AADavis_min, lat_AADavis_max, lon_AADavis_min, lon_AADavis_max = -90.0, -60.0, 59.0, 167.0

# %%
projection_map = ccrs.PlateCarree(central_longitude=180.0)
figMap,axMap = plt.subplots(nrows=1, ncols=1, subplot_kw={'projection':projection_map}, figsize=(16,8))

# PACIFIC

# East Pacific
cycle = tb.cycle_plot_rect_zone(lon_EPac1_min, lon_EPac1_max, lat_EPac1_min, lat_EPac1_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="East Pacific")
cycle = tb.cycle_plot_rect_zone(lon_EPac2_min, lon_EPac2_max, lat_EPac2_min, lat_EPac2_max)
axMap.fill(cycle[0], cycle[1], color='blue',linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EPac3_min, lon_EPac3_max, lat_EPac3_min, lat_EPac3_max)
axMap.fill(cycle[0], cycle[1], color='blue',linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EPac4_min, lon_EPac4_max, lat_EPac4_min, lat_EPac4_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-",alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EPac5_min, lon_EPac5_max, lat_EPac5_min, lat_EPac5_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-",alpha = 0.3, transform=ccrs.PlateCarree())

# Russia Pacific
cycle = tb.cycle_plot_rect_zone(lon_RussPac1_min, lon_RussPac1_max, lat_RussPac1_min, lat_RussPac1_max)
axMap.fill(cycle[0], cycle[1], color='red', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Russian Pacific")

# New Zealand (South)
cycle = tb.cycle_plot_rect_zone(lon_SNZPac1_min, lon_SNZPac1_max, lat_SNZPac1_min, lat_SNZPac1_max)
axMap.fill(cycle[0], cycle[1], color='green',linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="New Zealand (South)")

# New Zealand (North)
cycle = tb.cycle_plot_rect_zone(lon_NNZPac1_min, lon_NNZPac1_max, lat_NNZPac1_min, lat_NNZPac1_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="New Zealand (North)")

axMap.set_global()
axMap.coastlines()
axMap.legend(loc="upper right")

# %%
projection_map = ccrs.PlateCarree(central_longitude=70.0)
figMap,axMap = plt.subplots(nrows=1, ncols=1, subplot_kw={'projection':projection_map}, figsize=(16,8))

# ARCTIC

# Atlantic Greenland Iceland
cycle = tb.cycle_plot_rect_zone(lon_AtlGr1_min, lon_AtlGr1_max, lat_AtlGr1_min, lat_AtlGr1_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Atlantic Greenland & Iceland")
cycle = tb.cycle_plot_rect_zone(lon_AtlGr2_min, lon_AtlGr2_max, lat_AtlGr2_min, lat_AtlGr2_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# E Greenland & Iceland
cycle = tb.cycle_plot_rect_zone(lon_EGrIce1_min, lon_EGrIce1_max, lat_EGrIce1_min, lat_EGrIce1_max)
axMap.fill(cycle[0], cycle[1], color='red', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="East Greenland & Iceland")
cycle = tb.cycle_plot_rect_zone(lon_EGrIce2_min, lon_EGrIce2_max, lat_EGrIce2_min, lat_EGrIce2_max)
axMap.fill(cycle[0], cycle[1], color='red', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())


# E Iceland
cycle = tb.cycle_plot_rect_zone(lon_EIceland1_min, lon_EIceland1_max, lat_EIceland1_min, lat_EIceland1_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="East Iceland")

# UK Atlantic
cycle = tb.cycle_plot_rect_zone(lon_UKAtl1_min, lon_UKAtl1_max, lat_UKAtl1_min, lat_UKAtl1_max)
axMap.fill(cycle[0], cycle[1], color='orange', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="UK Atlantic")

# Eurasian GIN Seas
cycle = tb.cycle_plot_rect_zone(lon_EurGIN1_min, lon_EurGIN1_max, lat_EurGIN1_min, lat_EurGIN1_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Eurasian GIN Seas")
cycle = tb.cycle_plot_rect_zone(lon_EurGIN2_min, lon_EurGIN2_max, lat_EurGIN2_min, lat_EurGIN2_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN3_min, lon_EurGIN3_max, lat_EurGIN3_min, lat_EurGIN3_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN4_min, lon_EurGIN4_max, lat_EurGIN4_min, lat_EurGIN4_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN5_min, lon_EurGIN5_max, lat_EurGIN5_min, lat_EurGIN5_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN6_min, lon_EurGIN6_max, lat_EurGIN6_min, lat_EurGIN6_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_Baltic1_min, lon_Baltic1_max, lat_Baltic1_min, lat_Baltic1_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_Baltic2_min, lon_Baltic2_max, lat_Baltic2_min, lat_Baltic2_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# South Iceland
cycle = tb.cycle_plot_rect_zone(lon_SIceland1_min, lon_SIceland1_max, lat_SIceland1_min, lat_SIceland1_max)
axMap.fill(cycle[0], cycle[1], color='yellow', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="South Iceland")

# Siberian Arctic
cycle = tb.cycle_plot_rect_zone(lon_SibArc1_min, lon_SibArc1_max, lat_SibArc1_min, lat_SibArc1_max)
axMap.fill(cycle[0], cycle[1], color='brown', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Siberian Arctic")
cycle = tb.cycle_plot_rect_zone(lon_SibArc2_min, lon_SibArc2_max, lat_SibArc2_min, lat_SibArc2_max)
axMap.fill(cycle[0], cycle[1], color='brown', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# Eurasian Arctic
cycle = tb.cycle_plot_rect_zone(lon_EurArc1_min, lon_EurArc1_max, lat_EurArc1_min, lat_EurArc1_max)
axMap.fill(cycle[0], cycle[1], color='grey', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Eurasian Arctic")
cycle = tb.cycle_plot_rect_zone(lon_EurArc2_min, lon_EurArc2_max, lat_EurArc2_min, lat_EurArc2_max)
axMap.fill(cycle[0], cycle[1], color='grey', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurArc3_min, lon_EurArc3_max, lat_EurArc3_min, lat_EurArc3_max)
axMap.fill(cycle[0], cycle[1], color='grey', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

axMap.set_global()
axMap.coastlines()
axMap.legend(loc="upper right")

# %%
projection_map = ccrs.PlateCarree(central_longitude=70.0)
figMap,axMap = plt.subplots(nrows=1, ncols=1, subplot_kw={'projection':projection_map}, figsize=(16,8))

## NORTH ATLANTIC

# USA East Coast
cycle = tb.cycle_plot_rect_zone(lon_USECoast1_min, lon_USECoast1_max, lat_USECoast1_min, lat_USECoast1_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="USA East Coast")
cycle = tb.cycle_plot_rect_zone(lon_USECoast2_min, lon_USECoast2_max, lat_USECoast2_min, lat_USECoast2_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast3_min, lon_USECoast3_max, lat_USECoast3_min, lat_USECoast3_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast4_min, lon_USECoast4_max, lat_USECoast4_min, lat_USECoast4_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast5_min, lon_USECoast5_max, lat_USECoast5_min, lat_USECoast5_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast6_min, lon_USECoast6_max, lat_USECoast6_min, lat_USECoast6_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# Greenland Arctic
cycle = tb.cycle_plot_rect_zone(lon_GrArc1_min, lon_GrArc1_max, lat_GrArc1_min, lat_GrArc1_max)
axMap.fill(cycle[0], cycle[1], color='red', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Greenland Arctic")

# North American Arctic
cycle = tb.cycle_plot_rect_zone(lon_NAMArc1_min, lon_NAMArc1_max, lat_NAMArc1_min, lat_NAMArc1_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="North American Arctic")
cycle = tb.cycle_plot_rect_zone(lon_NAMArc2_min, lon_NAMArc2_max, lat_NAMArc2_min, lat_NAMArc2_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc3_min, lon_NAMArc3_max, lat_NAMArc3_min, lat_NAMArc3_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc4_min, lon_NAMArc4_max, lat_NAMArc4_min, lat_NAMArc4_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc5_min, lon_NAMArc5_max, lat_NAMArc5_min, lat_NAMArc5_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NWTerr1_min, lon_NWTerr1_max, lat_NWTerr1_min, lat_NWTerr1_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NWTerr2_min, lon_NWTerr2_max, lat_NWTerr2_min, lat_NWTerr2_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# Great Lakes
cycle = tb.cycle_plot_rect_zone(lon_GrLakes1_min, lon_GrLakes1_max, lat_GrLakes1_min, lat_GrLakes1_max)
axMap.fill(cycle[0], cycle[1], color='yellow', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Great Lakes")

# Gulf of Mexico
cycle = tb.cycle_plot_rect_zone(lon_GoM1_min, lon_GoM1_max, lat_GoM1_min, lat_GoM1_max)
axMap.fill(cycle[0], cycle[1], color='orange', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Gulf of Mexico")

# Mediterranean

cycle = tb.cycle_plot_rect_zone(lon_Med1_min, lon_Med1_max, lat_Med1_min, lat_Med1_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Mediterranean Sea")
cycle = tb.cycle_plot_rect_zone(lon_Med2_min, lon_Med2_max, lat_Med2_min, lat_Med2_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_BlckSea1_min, lon_BlckSea1_max, lat_BlckSea1_min, lat_BlckSea1_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_CaspSea1_min, lon_CaspSea1_max, lat_CaspSea1_min, lat_CaspSea1_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# Labrador Sea & Baffin Bay
cycle = tb.cycle_plot_rect_zone(lon_BafLab1_min, lon_BafLab1_max, lat_BafLab1_min, lat_BafLab1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Baffin and Hudson Bay")
cycle = tb.cycle_plot_rect_zone(lon_BafLab2_min, lon_BafLab2_max, lat_BafLab2_min, lat_BafLab2_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_BafLab3_min, lon_BafLab3_max, lat_BafLab3_min, lat_BafLab3_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_HudBay1_min, lon_HudBay1_max, lat_HudBay1_min, lat_HudBay1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_HudBay2_min, lon_HudBay2_max, lat_HudBay2_min, lat_HudBay2_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

axMap.set_global()
axMap.coastlines()
axMap.legend(loc="upper right")

# %%
projection_map = ccrs.PlateCarree(central_longitude=70.0)
figMap,axMap = plt.subplots(nrows=1, ncols=1, subplot_kw={'projection':projection_map}, figsize=(16,8))

## ANTARCTICA


# Patagonia Atlantic
cycle = tb.cycle_plot_rect_zone(lon_PatAtl1_min, lon_PatAtl1_max, lat_PatAtl1_min, lat_PatAtl1_max)
axMap.fill(cycle[0], cycle[1], color='blue', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Patagonia Atlantic")

# Patagonia Pacific
cycle = tb.cycle_plot_rect_zone(lon_PatPac1_min, lon_PatPac1_max, lat_PatPac1_min, lat_PatPac1_max)
axMap.fill(cycle[0], cycle[1], color='red', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Patagonia Pacific")
cycle = tb.cycle_plot_rect_zone(lon_PatPac2_min, lon_PatPac2_max, lat_PatPac2_min, lat_PatPac2_max)
axMap.fill(cycle[0], cycle[1], color='red', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree())

# Antarctic Ross Sea
cycle = tb.cycle_plot_rect_zone(lon_AARos1_min, lon_AARos1_max, lat_AARos1_min, lat_AARos1_max)
axMap.fill(cycle[0], cycle[1], color='green', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Antarctic Ross Sea")

# Antarctic Amundsen Sea
cycle = tb.cycle_plot_rect_zone(lon_AAAmund_min, lon_AAAmund_max, lat_AAAmund_min, lat_AAAmund_max)
axMap.fill(cycle[0], cycle[1], color='yellow', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Antarctic Amundsen Sea")

# Antarctic Weddell Sea
cycle = tb.cycle_plot_rect_zone(lon_AAWeddell_min, lon_AAWeddell_max, lat_AAWeddell_min, lat_AAWeddell_max)
axMap.fill(cycle[0], cycle[1], color='purple', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Antarctic Weddell Sea")

# Antarctic Riiser-Larson Sea
cycle = tb.cycle_plot_rect_zone(lon_AARiiLar_min, lon_AARiiLar_max, lat_AARiiLar_min, lat_AARiiLar_max)
axMap.fill(cycle[0], cycle[1], color='brown', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Antarctic Riiser-Larson Sea")

# Antarctic Davis Sea
cycle = tb.cycle_plot_rect_zone(lon_AADavis_min, lon_AADavis_max, lat_AADavis_min, lat_AADavis_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = "-", alpha = 0.3, transform=ccrs.PlateCarree(), label="Antarctic Davis Sea")

axMap.set_global()
axMap.coastlines()
axMap.legend(loc="center right")

# %% [markdown]
# ## Zone summary

# %%
ds_lsm = xr.open_dataset("/Documents/Documents/Cours/PHD/data/Proj_GLAC1D/ocean_masks/teadv3.qrparm.omask.nc")
lsm = ds_lsm.lsm.values
lat, lon = ds_lsm.latitude.values, ds_lsm.longitude.values
lat_b, lon_b = tb.create_coordinate_edges(lat), tb.create_coordinate_edges(lon)

ds_flux = xr.open_dataset("/Documents/Documents/Cours/PHD/data/Proj_GLAC1D/teadv3.qrparm.waterfix_GLAC1D_DEGLAC_s.nc", decode_times=False)
lon_wf, lat_wf = ds_flux.longitude.values, ds_flux.latitude.values
ds_values = np.where(np.isnan(ds_flux.discharge.values), 0, ds_flux.discharge.values)
values = np.multiply(ds_values / 1000 * 10 ** (-6),
                     tb.surface_matrix(ds_flux.longitude.values, ds_flux.latitude.values))
time = ds_flux.t.values
n_t = len(time)

# %%
projection_map = ccrs.PlateCarree(central_longitude=70.0)
figMap,axMap = plt.subplots(nrows=1, ncols=1, subplot_kw={'projection':projection_map}, figsize=(14,7), dpi=500)

## NORTH ATLANTIC + EUROPE

# USA East Coast
cycle = tb.cycle_plot_rect_zone(lon_USECoast1_min, lon_USECoast1_max, lat_USECoast1_min, lat_USECoast1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree(), label="North America Atlantic")
cycle = tb.cycle_plot_rect_zone(lon_USECoast2_min, lon_USECoast2_max, lat_USECoast2_min, lat_USECoast2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast3_min, lon_USECoast3_max, lat_USECoast3_min, lat_USECoast3_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast4_min, lon_USECoast4_max, lat_USECoast4_min, lat_USECoast4_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast5_min, lon_USECoast5_max, lat_USECoast5_min, lat_USECoast5_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_USECoast6_min, lon_USECoast6_max, lat_USECoast6_min, lat_USECoast6_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Labrador Sea & Baffin Bay
cycle = tb.cycle_plot_rect_zone(lon_BafLab1_min, lon_BafLab1_max, lat_BafLab1_min, lat_BafLab1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_BafLab2_min, lon_BafLab2_max, lat_BafLab2_min, lat_BafLab2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_BafLab3_min, lon_BafLab3_max, lat_BafLab3_min, lat_BafLab3_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_HudBay1_min, lon_HudBay1_max, lat_HudBay1_min, lat_HudBay1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_HudBay2_min, lon_HudBay2_max, lat_HudBay2_min, lat_HudBay2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Great Lakes
cycle = tb.cycle_plot_rect_zone(lon_GrLakes1_min, lon_GrLakes1_max, lat_GrLakes1_min, lat_GrLakes1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Gulf of Mexico
cycle = tb.cycle_plot_rect_zone(lon_GoM1_min, lon_GoM1_max, lat_GoM1_min, lat_GoM1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:sky blue', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())



# UK Atlantic
cycle = tb.cycle_plot_rect_zone(lon_UKAtl1_min, lon_UKAtl1_max, lat_UKAtl1_min, lat_UKAtl1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree(), label="Nordic seas")

# Eurasian GIN Seas
cycle = tb.cycle_plot_rect_zone(lon_EurGIN1_min, lon_EurGIN1_max, lat_EurGIN1_min, lat_EurGIN1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN2_min, lon_EurGIN2_max, lat_EurGIN2_min, lat_EurGIN2_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN3_min, lon_EurGIN3_max, lat_EurGIN3_min, lat_EurGIN3_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN4_min, lon_EurGIN4_max, lat_EurGIN4_min, lat_EurGIN4_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN5_min, lon_EurGIN5_max, lat_EurGIN5_min, lat_EurGIN5_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurGIN6_min, lon_EurGIN6_max, lat_EurGIN6_min, lat_EurGIN6_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_Baltic1_min, lon_Baltic1_max, lat_Baltic1_min, lat_Baltic1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_Baltic2_min, lon_Baltic2_max, lat_Baltic2_min, lat_Baltic2_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# South Iceland
cycle = tb.cycle_plot_rect_zone(lon_SIceland1_min, lon_SIceland1_max, lat_SIceland1_min, lat_SIceland1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Atlantic Greenland Iceland
cycle = tb.cycle_plot_rect_zone(lon_AtlGr1_min, lon_AtlGr1_max, lat_AtlGr1_min, lat_AtlGr1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_AtlGr2_min, lon_AtlGr2_max, lat_AtlGr2_min, lat_AtlGr2_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# E Greenland & Iceland
cycle = tb.cycle_plot_rect_zone(lon_EGrIce1_min, lon_EGrIce1_max, lat_EGrIce1_min, lat_EGrIce1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EGrIce2_min, lon_EGrIce2_max, lat_EGrIce2_min, lat_EGrIce2_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# E Iceland
cycle = tb.cycle_plot_rect_zone(lon_EIceland1_min, lon_EIceland1_max, lat_EIceland1_min, lat_EIceland1_max)
axMap.fill(cycle[0], cycle[1], color='coral', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

## MEDITERANNEAN SEA

# Mediterranean

cycle = tb.cycle_plot_rect_zone(lon_Med1_min, lon_Med1_max, lat_Med1_min, lat_Med1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:olive', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree(), label="Mediterannean")
cycle = tb.cycle_plot_rect_zone(lon_Med2_min, lon_Med2_max, lat_Med2_min, lat_Med2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:olive', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_BlckSea1_min, lon_BlckSea1_max, lat_BlckSea1_min, lat_BlckSea1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:olive', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_CaspSea1_min, lon_CaspSea1_max, lat_CaspSea1_min, lat_CaspSea1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:olive', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())


# ARCTIC

# Greenland Arctic
cycle = tb.cycle_plot_rect_zone(lon_GrArc1_min, lon_GrArc1_max, lat_GrArc1_min, lat_GrArc1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree(), label="Arctic")

# North American Arctic
cycle = tb.cycle_plot_rect_zone(lon_NAMArc1_min, lon_NAMArc1_max, lat_NAMArc1_min, lat_NAMArc1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc2_min, lon_NAMArc2_max, lat_NAMArc2_min, lat_NAMArc2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc3_min, lon_NAMArc3_max, lat_NAMArc3_min, lat_NAMArc3_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc4_min, lon_NAMArc4_max, lat_NAMArc4_min, lat_NAMArc4_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NAMArc5_min, lon_NAMArc5_max, lat_NAMArc5_min, lat_NAMArc5_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NWTerr1_min, lon_NWTerr1_max, lat_NWTerr1_min, lat_NWTerr1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_NWTerr2_min, lon_NWTerr2_max, lat_NWTerr2_min, lat_NWTerr2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Siberian Arctic
cycle = tb.cycle_plot_rect_zone(lon_SibArc1_min, lon_SibArc1_max, lat_SibArc1_min, lat_SibArc1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_SibArc2_min, lon_SibArc2_max, lat_SibArc2_min, lat_SibArc2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Eurasian Arctic
cycle = tb.cycle_plot_rect_zone(lon_EurArc1_min, lon_EurArc1_max, lat_EurArc1_min, lat_EurArc1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurArc2_min, lon_EurArc2_max, lat_EurArc2_min, lat_EurArc2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EurArc3_min, lon_EurArc3_max, lat_EurArc3_min, lat_EurArc3_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:blue green', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())


## SOUTHERN SEAS

# Patagonia Atlantic
cycle = tb.cycle_plot_rect_zone(lon_PatAtl1_min, lon_PatAtl1_max, lat_PatAtl1_min, lat_PatAtl1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree(), label="Southern seas")

# Patagonia Pacific
cycle = tb.cycle_plot_rect_zone(lon_PatPac1_min, lon_PatPac1_max, lat_PatPac1_min, lat_PatPac1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_PatPac2_min, lon_PatPac2_max, lat_PatPac2_min, lat_PatPac2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Antarctic Ross Sea
cycle = tb.cycle_plot_rect_zone(lon_AARos1_min, lon_AARos1_max, lat_AARos1_min, lat_AARos1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Antarctic Amundsen Sea
cycle = tb.cycle_plot_rect_zone(lon_AAAmund_min, lon_AAAmund_max, lat_AAAmund_min, lat_AAAmund_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Antarctic Weddell Sea
cycle = tb.cycle_plot_rect_zone(lon_AAWeddell_min, lon_AAWeddell_max, lat_AAWeddell_min, lat_AAWeddell_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Antarctic Riiser-Larson Sea
cycle = tb.cycle_plot_rect_zone(lon_AARiiLar_min, lon_AARiiLar_max, lat_AARiiLar_min, lat_AARiiLar_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# Antarctic Davis Sea
cycle = tb.cycle_plot_rect_zone(lon_AADavis_min, lon_AADavis_max, lat_AADavis_min, lat_AADavis_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:lavender', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())


# PACIFIC

# East Pacific
cycle = tb.cycle_plot_rect_zone(lon_EPac1_min, lon_EPac1_max, lat_EPac1_min, lat_EPac1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree(), label="Pacific")
cycle = tb.cycle_plot_rect_zone(lon_EPac2_min, lon_EPac2_max, lat_EPac2_min, lat_EPac2_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard',linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EPac3_min, lon_EPac3_max, lat_EPac3_min, lat_EPac3_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard',linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EPac4_min, lon_EPac4_max, lat_EPac4_min, lat_EPac4_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard', linestyle = '-', linewidth = 0,alpha = 0.3, transform=ccrs.PlateCarree())
cycle = tb.cycle_plot_rect_zone(lon_EPac5_min, lon_EPac5_max, lat_EPac5_min, lat_EPac5_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard', linestyle = '-', linewidth = 0,alpha = 0.3, transform=ccrs.PlateCarree())

# Russia Pacific
cycle = tb.cycle_plot_rect_zone(lon_RussPac1_min, lon_RussPac1_max, lat_RussPac1_min, lat_RussPac1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# New Zealand (South)
cycle = tb.cycle_plot_rect_zone(lon_SNZPac1_min, lon_SNZPac1_max, lat_SNZPac1_min, lat_SNZPac1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard',linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())

# New Zealand (North)
cycle = tb.cycle_plot_rect_zone(lon_NNZPac1_min, lon_NNZPac1_max, lat_NNZPac1_min, lat_NNZPac1_max)
axMap.fill(cycle[0], cycle[1], color='xkcd:mustard', linestyle = '-', linewidth = 0, alpha = 0.3, transform=ccrs.PlateCarree())


axMap.pcolormesh(lon_b, lat_b, lsm, transform=ccrs.PlateCarree(),cmap="binary", alpha = 0.2)

axMap.set_global()
axMap.set_title("Spreading Map")
axMap.legend(loc="center right")

# %% [markdown]
# ## Flux time serie

# %%
flux_nam = [0] * n_t
flux_nor = [0] * n_t
flux_med = [0] * n_t
flux_arc = [0] * n_t
flux_sou = [0] * n_t
flux_pac = [0] * n_t
flux_tot = [0] * n_t

for t in range(n_t):
    vt = values[t]
    
    flux_nam[t] += tb.sum_rect_zone(vt, lon_USECoast1_min, lon_USECoast1_max, lat_USECoast1_min, lat_USECoast1_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_USECoast2_min, lon_USECoast2_max, lat_USECoast2_min, lat_USECoast2_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_USECoast3_min, lon_USECoast3_max, lat_USECoast3_min, lat_USECoast3_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_USECoast4_min, lon_USECoast4_max, lat_USECoast4_min, lat_USECoast4_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_USECoast5_min, lon_USECoast5_max, lat_USECoast5_min, lat_USECoast5_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_USECoast6_min, lon_USECoast6_max, lat_USECoast6_min, lat_USECoast6_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_BafLab1_min, lon_BafLab1_max, lat_BafLab1_min, lat_BafLab1_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_BafLab2_min, lon_BafLab2_max, lat_BafLab2_min, lat_BafLab2_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_BafLab3_min, lon_BafLab3_max, lat_BafLab3_min, lat_BafLab3_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_HudBay1_min, lon_HudBay1_max, lat_HudBay1_min, lat_HudBay1_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_HudBay2_min, lon_HudBay2_max, lat_HudBay2_min, lat_HudBay2_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_GrLakes1_min, lon_GrLakes1_max, lat_GrLakes1_min, lat_GrLakes1_max, lon_wf, lat_wf, None)
    flux_nam[t] += tb.sum_rect_zone(vt, lon_GoM1_min, lon_GoM1_max, lat_GoM1_min, lat_GoM1_max, lon_wf, lat_wf, None)

    flux_nor[t] += tb.sum_rect_zone(vt, lon_UKAtl1_min, lon_UKAtl1_max, lat_UKAtl1_min, lat_UKAtl1_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EurGIN1_min, lon_EurGIN1_max, lat_EurGIN1_min, lat_EurGIN1_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EurGIN2_min, lon_EurGIN2_max, lat_EurGIN2_min, lat_EurGIN2_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EurGIN3_min, lon_EurGIN3_max, lat_EurGIN3_min, lat_EurGIN3_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EurGIN4_min, lon_EurGIN4_max, lat_EurGIN4_min, lat_EurGIN4_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EurGIN5_min, lon_EurGIN5_max, lat_EurGIN5_min, lat_EurGIN5_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EurGIN6_min, lon_EurGIN6_max, lat_EurGIN6_min, lat_EurGIN6_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_Baltic1_min, lon_Baltic1_max, lat_Baltic1_min, lat_Baltic1_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_Baltic2_min, lon_Baltic2_max, lat_Baltic2_min, lat_Baltic2_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_SIceland1_min, lon_SIceland1_max, lat_SIceland1_min, lat_SIceland1_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_AtlGr1_min, lon_AtlGr1_max, lat_AtlGr1_min, lat_AtlGr1_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_AtlGr2_min, lon_AtlGr2_max, lat_AtlGr2_min, lat_AtlGr2_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EGrIce1_min, lon_EGrIce1_max, lat_EGrIce1_min, lat_EGrIce1_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EGrIce2_min, lon_EGrIce2_max, lat_EGrIce2_min, lat_EGrIce2_max, lon_wf, lat_wf, None)
    flux_nor[t] += tb.sum_rect_zone(vt, lon_EIceland1_min, lon_EIceland1_max, lat_EIceland1_min, lat_EIceland1_max, lon_wf, lat_wf, None)

    flux_med[t] += tb.sum_rect_zone(vt, lon_Med1_min, lon_Med1_max, lat_Med1_min, lat_Med1_max, lon_wf, lat_wf, None)
    flux_med[t] += tb.sum_rect_zone(vt, lon_Med2_min, lon_Med2_max, lat_Med2_min, lat_Med2_max, lon_wf, lat_wf, None)
    flux_med[t] += tb.sum_rect_zone(vt, lon_BlckSea1_min, lon_BlckSea1_max, lat_BlckSea1_min, lat_BlckSea1_max, lon_wf, lat_wf, None)
    flux_med[t] += tb.sum_rect_zone(vt, lon_CaspSea1_min, lon_CaspSea1_max, lat_CaspSea1_min, lat_CaspSea1_max, lon_wf, lat_wf, None)

    flux_arc[t] += tb.sum_rect_zone(vt, lon_GrArc1_min, lon_GrArc1_max, lat_GrArc1_min, lat_GrArc1_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NAMArc1_min, lon_NAMArc1_max, lat_NAMArc1_min, lat_NAMArc1_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NAMArc2_min, lon_NAMArc2_max, lat_NAMArc2_min, lat_NAMArc2_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NAMArc3_min, lon_NAMArc3_max, lat_NAMArc3_min, lat_NAMArc3_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NAMArc4_min, lon_NAMArc4_max, lat_NAMArc4_min, lat_NAMArc4_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NAMArc5_min, lon_NAMArc5_max, lat_NAMArc5_min, lat_NAMArc5_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NWTerr1_min, lon_NWTerr1_max, lat_NWTerr1_min, lat_NWTerr1_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_NWTerr2_min, lon_NWTerr2_max, lat_NWTerr2_min, lat_NWTerr2_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_SibArc1_min, lon_SibArc1_max, lat_SibArc1_min, lat_SibArc1_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_SibArc2_min, lon_SibArc2_max, lat_SibArc2_min, lat_SibArc2_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_EurArc1_min, lon_EurArc1_max, lat_EurArc1_min, lat_EurArc1_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_EurArc2_min, lon_EurArc2_max, lat_EurArc2_min, lat_EurArc2_max, lon_wf, lat_wf, None)
    flux_arc[t] += tb.sum_rect_zone(vt, lon_EurArc3_min, lon_EurArc3_max, lat_EurArc3_min, lat_EurArc3_max, lon_wf, lat_wf, None)

    flux_sou[t] += tb.sum_rect_zone(vt, lon_PatAtl1_min, lon_PatAtl1_max, lat_PatAtl1_min, lat_PatAtl1_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_PatPac1_min, lon_PatPac1_max, lat_PatPac1_min, lat_PatPac1_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_PatPac2_min, lon_PatPac2_max, lat_PatPac2_min, lat_PatPac2_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_AARos1_min, lon_AARos1_max, lat_AARos1_min, lat_AARos1_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_AAAmund_min, lon_AAAmund_max, lat_AAAmund_min, lat_AAAmund_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_AAWeddell_min, lon_AAWeddell_max, lat_AAWeddell_min, lat_AAWeddell_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_AARiiLar_min, lon_AARiiLar_max, lat_AARiiLar_min, lat_AARiiLar_max, lon_wf, lat_wf, None)
    flux_sou[t] += tb.sum_rect_zone(vt, lon_AADavis_min, lon_AADavis_max, lat_AADavis_min, lat_AADavis_max, lon_wf, lat_wf, None)
    
    flux_pac[t] += tb.sum_rect_zone(vt, lon_EPac1_min, lon_EPac1_max, lat_EPac1_min, lat_EPac1_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_EPac2_min, lon_EPac2_max, lat_EPac2_min, lat_EPac2_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_EPac3_min, lon_EPac3_max, lat_EPac3_min, lat_EPac3_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_EPac4_min, lon_EPac4_max, lat_EPac4_min, lat_EPac4_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_EPac5_min, lon_EPac5_max, lat_EPac5_min, lat_EPac5_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_RussPac1_min, lon_RussPac1_max, lat_RussPac1_min, lat_RussPac1_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_SNZPac1_min, lon_SNZPac1_max, lat_SNZPac1_min, lat_SNZPac1_max, lon_wf, lat_wf, None)
    flux_pac[t] += tb.sum_rect_zone(vt, lon_NNZPac1_min, lon_NNZPac1_max, lat_NNZPac1_min, lat_NNZPac1_max, lon_wf, lat_wf, None)
    
    flux_tot[t] = flux_nam[t] + flux_nor[t] + flux_med[t] + flux_arc[t] + flux_sou[t] + flux_pac[t]
    print(f"____ Computation time step : {t}. Total flux : {flux_tot[t]}")
# Out:
# ____ Computation time step : 0. Total flux : 0.053672060400003586
# ____ Computation time step : 1. Total flux : 0.057299919916573294
# ____ Computation time step : 2. Total flux : 0.053431031344003385
# ____ Computation time step : 3. Total flux : 0.06657475473141965
# ____ Computation time step : 4. Total flux : 0.05841472232470005
# ____ Computation time step : 5. Total flux : 0.06762232906724529
# ____ Computation time step : 6. Total flux : 0.0722208135039391
# ____ Computation time step : 7. Total flux : 0.06815453448361712
# ____ Computation time step : 8. Total flux : 0.07148801924247214
# ____ Computation time step : 9. Total flux : 0.07690840553341709
# ____ Computation time step : 10. Total flux : 0.0712970646642863
# ____ Computation time step : 11. Total flux : 0.06627940579925869
# ____ Computation time step : 12. Total flux : 0.06595144409944727
# ____ Computation time step : 13. Total flux : 0.05722154246001065
# ...

# %%
figMap, axMap = plt.subplots(nrows=1, ncols=1, figsize=(14, 8), dpi=400)

flux_nam = tb.running_mean(flux_nam,10)
flux_nor = tb.running_mean(flux_nor,10)
flux_med = tb.running_mean(flux_med,10)
flux_arc = tb.running_mean(flux_arc,10)
flux_sou = tb.running_mean(flux_sou,10)
flux_pac = tb.running_mean(flux_pac,10)
flux_tot = tb.running_mean(flux_tot,10)

axMap.plot(time[:51], flux_nam[:51], color="xkcd:sky blue", linestyle="-", alpha=0.3)
axMap.plot(time[:51], flux_nor[:51], color="coral", linestyle="-", alpha=0.3)
axMap.plot(time[:51], flux_med[:51], color="xkcd:olive", linestyle="-", alpha=0.3)
axMap.plot(time[:51], flux_arc[:51], color="xkcd:blue green", linestyle="-", alpha=0.3)
axMap.plot(time[:51], flux_sou[:51], color="xkcd:lavender", linestyle="-", alpha=0.3)
axMap.plot(time[:51], flux_pac[:51], color="xkcd:mustard", linestyle="-", alpha=0.3)
axMap.plot(time[:51], flux_tot[:51], color="black", linestyle="-", alpha=0.3)

axMap.plot(time[50:151], flux_nam[50:151], label="North America Atlantic", color="xkcd:sky blue", linestyle="-")
axMap.plot(time[50:151], flux_nor[50:151], label="Nordic seas", color="coral", linestyle="-")
axMap.plot(time[50:151], flux_med[50:151], label="Mediteranean", color="xkcd:olive", linestyle="-")
axMap.plot(time[50:151], flux_arc[50:151], label="Arctic", color="xkcd:blue green", linestyle="-")
axMap.plot(time[50:151], flux_sou[50:151], label="Southern seas", color="xkcd:lavender", linestyle="-")
axMap.plot(time[50:151], flux_pac[50:151], label="Pacific", color="xkcd:mustard", linestyle="-")
axMap.plot(time[50:151], flux_tot[50:151], label="Total", color="black", linestyle="-")

axMap.plot(time[150:], flux_nam[150:], color="xkcd:sky blue", linestyle="-", alpha=0.3)
axMap.plot(time[150:], flux_nor[150:], color="coral", linestyle="-", alpha=0.3)
axMap.plot(time[150:], flux_med[150:], color="xkcd:olive", linestyle="-", alpha=0.3)
axMap.plot(time[150:], flux_arc[150:], color="xkcd:blue green", linestyle="-", alpha=0.3)
axMap.plot(time[150:], flux_sou[150:], color="xkcd:lavender", linestyle="-", alpha=0.3)
axMap.plot(time[150:], flux_pac[150:], color="xkcd:mustard", linestyle="-", alpha=0.3)
axMap.plot(time[150:], flux_tot[150:], color="black", linestyle="-", alpha=0.3)

axMap.set_ylabel("Meltwater flux (Sv)")
axMap.ticklabel_format(style="sci")
axMap.legend(loc="upper right")
axMap.set_xlabel("Years")
axMap.set_title("Meltwater Discharge")
# Out:
# Text(0.5, 1.0, 'Meltwater Discharge')

# %% [markdown]
# ## Equilibrium run

# %%
ds = xr.open_dataset("/Documents/Documents/Cours/PHD/data/xosfa/xosfa.oceansalipg01.annual.nc")
sss = np.nanmean(ds.salinity_ym_dpth.values * 1000 + 35, axis=(1,2,3))
sss_m = tb.running_mean(sss,10)

ds = xr.open_dataset("/Documents/Documents/Cours/PHD/data/xosfa/xosfa.oceantemppg01.annual.nc")
sst = np.nanmean(ds.temp_ym_dpth.values, axis=(1,2,3))
sst_m = tb.running_mean(sst,10)

time = np.arange(len(sss))

# %%
figMap, (axSST, axSSS) = plt.subplots(nrows=2, ncols=1, figsize=(14, 14), dpi=400)

axSST.plot(time, sst_m, color="xkcd:sky blue", linestyle="-")
axSST.plot(time, sst, color="xkcd:sky blue", linestyle="-", alpha = 0.3)
axSST.set_ylabel("Global mean SST (°C)")
axSST.ticklabel_format(style="sci")
axSST.set_xlabel("Simulation Years")

axSSS.plot(time, sss_m, color="xkcd:sky blue", linestyle="-")
axSSS.plot(time, sss, color="xkcd:sky blue", linestyle="-", alpha = 0.3)
axSSS.set_ylabel("Global mean SSS (PSU)")
axSSS.ticklabel_format(style="sci")
axSSS.set_xlabel("Simulation Years")
# Out:
# Text(0.5, 0, 'Simulation Years')

# %% [markdown]
# ## Experiments
